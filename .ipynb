# %%
import pandas as pd
df = pd.read_csv('model_comparison_results.csv')

# %%
df.sort_values(by='Accuracy', ascending=False).head(20)
# Out:
#                    Model          Outliers          Scaling  \
# 170  Logistic Regression  Without Outliers    Normalization
# 140  Logistic Regression  Without Outliers  Standardization
# 177        Random Forest  Without Outliers    Normalization
# 153                  SVM  Without Outliers    Normalization
# 150  Logistic Regression  Without Outliers    Normalization
# 120  Logistic Regression  Without Outliers  Standardization
# 145  Logistic Regression  Without Outliers  Standardization
# 107        Random Forest  Without Outliers       No Scaling
# 175  Logistic Regression  Without Outliers    Normalization
# 117        Random Forest  Without Outliers       No Scaling
# 168                  SVM  Without Outliers    Normalization
# 137        Random Forest  Without Outliers  Standardization
# 167        Random Forest  Without Outliers    Normalization
# 147        Random Forest  Without Outliers  Standardization
# 178                  SVM  Without Outliers    Normalization
# ...
